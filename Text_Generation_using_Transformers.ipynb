# %% [markdown]
# # Text Generation using Transformers

# %% [markdown]
# ## Installing Libraries

# %%
# %%capture
# !pip install transformers torch --quiet

# %% [markdown]
# ## Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# ## Loading pre-trained Model & Tokenizer

# %%
# Model: GPT-Neo 1.3B (larger and stronger than GPT-2)
model_name = "EleutherAI/gpt-neo-1.3B"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Set pad token if missing
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]

# %% [markdown]
# ## Functions

# %%
def generate_text_from_model(prompt, max_length=100, temperature=0.7, top_k=50, top_p=0.95):
    # Tokenize prompt
    input_ids = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones_like(input_ids)

    # Generate text with sampling
    output = model.generate(
        input_ids=input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        pad_token_id=tokenizer.pad_token_id
    )

    # Decode and return
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %% [markdown]
# ##Text Generation Interface

# %%
def text_generation():
    print("Enter 'exit' to quit.\n")
    while True:
        prompt = input("Enter prompt: ")
        if prompt.lower() == 'exit':
            break
        result = generate_text_from_model(prompt)
        print("\nGenerated Text:\n", result)
        print("-" * 80)

# %%
text_generation()
# Out:
# Enter 'exit' to quit.
#
# Enter prompt: i love beach
#
# Generated Text:
#  i love beach house
#
# This is a guest post by Toni B. It was originally published on May 30, 2014.
# Toni is the author of “Losing It: The Surreal Story of Our Relationship with Food”. The book was released in the fall of 2013 by Three Rivers Press. As an author, T.B. writes about her relationship with food and the impact it has on her and her family. She is currently studying to earn a Master’
# --------------------------------------------------------------------------------
# Enter prompt: billie eilish
#
# Generated Text:
#  billie eilish
#
# Monday, July 3, 2013
# 4:30pm
# 1st Floor
# Bishop's Stortford
# Stortfords Hospital
# Wycombe Road, St.ortforth
# We are looking for volunteers to help with the
# Charity Shop.
# The shop has been in the same location for the past
# 12 years and is a great place to find great clothes. The
# shop is currently run by volunteers and we need help
# with the
# --------------------------------------------------------------------------------
# Enter prompt: bts
#
# Generated Text:
#  bts"
# 	"github.com/BurntSushi/toml"
#
# 	networking "k8s.io/client-go/net"   // for testing
# )
#
# // testData contains mock data used by the test code.
# type testdata struct {
# }
#
# --------------------------------------------------------------------------------
# Enter prompt: peach
#
# Generated Text:
#  peach the next time you come across it.
#
# I’ve been on both sides of this debate, and I‘ve seen how my parents and grandparents have handled it all. Some of them have said it was an easy decision to make and that they”ve done it for their children. I can“t believe that someone would even consider doing something like this and to me that‚s not something that anyone should be doing. If they did that, then
# --------------------------------------------------------------------------------
# Enter prompt: Write a paragraph about the K-pop band BTS and their global influence.
#
# Generated Text:
#  Write a paragraph about the K-pop band BTS and their global influence.
#
# The Kpopalypse
# (Kpop is a Korean acronym for “K-Pop” or ‘Korean Popular Culture’)
# is a global, non-profit organization that aims to promote KPop music. As such,
# KPopalyse is not just about K Pop, but also about Korean culture, in particular, the
# BTS. K pop is an amalg
# --------------------------------------------------------------------------------
# Enter prompt: Describe Billie Eilish’s music style and why she’s popular among young listeners.
#
# Generated Text:
#  Describe Billie Eilish’s music style and why she’s popular among young listeners.
#
# Billie is a singer-songwriter from Toronto. Her music is influenced by R&B, rock, and hip-hop. She has a wide array of influences, but one of her primary influences is R. Kelly. In the early 2000s, she started writing songs and writing her own material with R Kelly, who is one her main inspirations. I�
# --------------------------------------------------------------------------------
# Enter prompt: BTS Boy band
#
# Generated Text:
#  BTS Boy band
#
# The BTS boy band is an international boy group formed in Seoul, South Korea in 2016. They are currently known as a group of Korean artists, and are composed of members from different backgrounds. The group was formed by the Korean singer and actor J-Hope and his ex-wife, singer Bae Doona, who both sang and wrote the songs of the group.
# Their first Korean single "Pray" was released on November 18, 2016, through
# --------------------------------------------------------------------------------
# Enter prompt: seventeen boy band
#
# Generated Text:
#  seventeen boy band members to sing the chorus on the album.
#
# Track listing
# "This Is the Night" (Toni Basil) - 3:21
# "(I Can't Get No) Satisfaction"  (Diana Ross)  - 4:03
#  "This Town" - 2:47
#  "(I'll Be Around) Till I Drop" featuring Stevie Wonder (Bobby Fuller) (Tracks 1 & 2 from The Very Best of Diana Ross and The
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2314177272> in <cell line: 0>()
# ----> 1 text_generation()
#
# <ipython-input-9-1225115466> in text_generation()
#       2     print("Enter 'exit' to quit.\n")
#       3     while True:
# ----> 4         prompt = input("Enter prompt: ")
#       5         if prompt.lower() == 'exit':
#       6             break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
